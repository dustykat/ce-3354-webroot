# %% [markdown]
# ## Week 1: Introduction to Engineering Hydrology
# - Lecture 1: Importance of Hydrology in Engineering
#   - Hydrology in civil, environmental, and water resources engineering
#   - Role of hydrologists in design and management
# - Lecture 2: The Hydrologic Cycle
#   - Precipitation, evaporation, infiltration, runoff, and groundwater flow
#   - Global and regional water balance
#
# - Lab/Exercise: Simple water balance estimation using real-world data
#
# ## Week 2: Precipitation and Measurement Techniques
# - Lecture 3: Precipitation Characteristics
#   - Rainfall intensity, duration, and frequency
#   - Measurement techniques (rain gauges, radar, remote sensing)
# - Lecture 4: Design Storms and Frequency Analysis
#   - Intensity-Duration-Frequency (IDF) curves
#   - Return periods and probability distributions
#
# - Lab/Exercise: Estimating design storms using IDF curves
#
# ## Week 3: Infiltration and Soil Moisture
# - Lecture 5: Infiltration Process and Factors Affecting It
#   - Soil types, vegetation, land use, and surface conditions
#   - Horton and Green-Ampt equations
# - Lecture 6: Soil Moisture and Groundwater Recharge
#   - Field capacity, wilting point, and available moisture
#   - Percolation and aquifer recharge
#
# - Lab/Exercise: Infiltration measurement using field/lab methods
#
# ## Week 4: Runoff Generation and Watershed Hydrology
# - Lecture 7: Runoff Mechanisms and Flow Pathways
#   - Hortonian vs. Dunne overland flow
#   - Baseflow and interflow
# - Lecture 8: Watershed Characteristics and Delineation
#   - Watershed boundaries, area, slope, and land use
#   - Time of concentration and drainage network mapping
#
# - Lab/Exercise: Delineating a watershed using GIS or topographic maps
#
# ## Week 5: Rainfall-Runoff Relationships
# - Lecture 9: Rational Method and SCS Curve Number (CN) Method
#   - Q = CiA and its applications
#   - Curve Number method and runoff estimation
# - Lecture 10: Unit Hydrograph Theory
#   - Concept of hydrographs and peak flow estimation
#   - Synthetic vs. observed unit hydrographs
#
# - Lab/Exercise: Runoff estimation using Rational and CN methods
#
# ## Week 6: Streamflow Measurement and Hydrographs
# - Lecture 11: Streamflow Measurement Techniques
#   - Weirs, flumes, and velocity-area methods
#   - Rating curves and flow-duration curves
# - Lecture 12: Hydrograph Analysis and Baseflow Separation
#   - Stormflow vs. baseflow
#   - Recession curves and storage effects
#
# - Lab/Exercise: Streamflow data analysis and hydrograph interpretation
#
# ## Week 7: Flood Hydrology and Urban Hydrology
# - Lecture 13: Flood Estimation and Design Floods
#   - Flood frequency analysis (Log-Pearson Type III)
#   - Regional flood equations and statistical approaches
# - Lecture 14: Urban Hydrology and Stormwater Management
#   - Effects of urbanization on runoff and flooding
#   - Green infrastructure and detention basins
#
# - Lab/Exercise: Estimating peak flow for a given return period
#
# ## Week 8: Applications and Final Review
# - Lecture 15: Hydrology in Engineering Design
#   - Hydrologic modeling, climate change impacts, and water management
#   - Real-world case studies (dams, levees, stormwater systems)
# - Lecture 16: Course Review and Final Project Presentations
#   - Summary of key concepts and Q&A session
#   - Final Lab/Exercise: Group Project on a Hydrologic Case Study
#
# ## Week 9: Groundwater Fundamentals & Flow Equations
#
# - Lecture 17: Groundwater Occurrence & Aquifers
#   - Types of aquifers: confined, unconfined, perched
#   - Porosity, permeability, and storativity
#   - Interaction between surface water and groundwater
# - Lecture 18: Groundwater Flow Principles
#   - Darcy’s Law and hydraulic conductivity
#   - Flow in saturated vs. unsaturated zones
#   - Introduction to governing equations (Laplace, Dupuit-Forchheimer)
#
# - Lab/Exercise: Simple Darcy’s Law experiment using permeameters
#
# ## Week 10: Well Hydraulics & Groundwater Management
#
# - Lecture 19: Well Hydraulics & Pumping Tests
#   - Cone of depression and drawdown
#   - Theis and Thiem equations for well analysis
#   - Groundwater recharge and depletion issues
# - Lecture 20: Transient Well Hydraulics
#   - Theis solution for transient flow to a well
#   - Concept of storativity and time-dependent drawdown
#   - Cooper-Jacob approximation for late-time drawdown
# - Lecture 21: Groundwater Management & Sustainability
#   - Overdraft, subsidence, and long-term water balance
#   - Groundwater protection and contamination risks
#   - Case studies of aquifer depletion and management strategies
#
# - Lab/Exercise: Analyzing pumping test data using Theis and Cooper-Jacob methods
# - Lab/Exercise: Pumping test data analysis & groundwater modeling introduction
